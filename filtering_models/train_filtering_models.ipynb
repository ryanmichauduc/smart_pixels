# %%
import sys 
import os
parentdir = os.path.dirname(os.getcwd())
sys.path.insert(0, parentdir) 
from FilteringModel import *
# Out:
# 2025-06-06 13:02:22.950507: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-06 13:02:22.951045: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-06 13:02:22.953839: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-06 13:02:22.961935: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
model=FilteringModel(tf_records_dir=Path('./filtering_records2000test').resolve(), x_feature_description=['x_size', 'y_size', 'y_local', 'z_global'], loadModel=True, model_number=2)#pairInputs=True,addDirectPath=True, y_local_layer=[3,1], z_global_layer=[3,1],classification_layer=[3,1], nSteps=200,learning_rate=0.02)
# Out:
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# batches:  30
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# 2025-06-06 13:02:44.222895: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Compiling model with learning rate: 0.01

# %%
#model.compileModel(0.0005)
model.runTraining(plotTraining=True)
# Out:
# 2025-06-06 12:54:04.878313: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:370] TFRecordDataset `buffer_size` is unspecified, default to 262144
# Epoch 1/220
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - binary_accuracy: 0.5795 - loss: 0.7018 - val_binary_accuracy: 0.5701 - val_loss: 0.6849 - lr: 0.0073
# Epoch 2/220
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - binary_accuracy: 0.5516 - loss: 0.6795 - val_binary_accuracy: 0.6324 - val_loss: 0.6801 - lr: 0.0080
# Epoch 3/220
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - binary_accuracy: 0.5342 - loss: 0.6851 - val_binary_accuracy: 0.6460 - val_loss: 0.6771 - lr: 0.0087
# Epoch 4/220
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - binary_accuracy: 0.5513 - loss: 0.6865 - val_binary_accuracy: 0.6510 - val_loss: 0.6748 - lr: 0.0093
# Epoch 5/220
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - binary_accuracy: 0.5497 - loss: 0.6868 - val_binary_accuracy: 0.6609 - val_loss: 0.6722 - lr: 0.0100
# Epoch 6/220
# ...

# %%
model.checkAccuracy()
# Out:
# 2025-06-06 13:02:59.211829: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:370] TFRecordDataset `buffer_size` is unspecified, default to 262144
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step
# 100%|██████████| 7/7 [00:00<00:00, 19.39it/s]
# Overall Accuracy of Neural Network: 84.14%
# Fraction of Data that are Signal: 55.5%
#
# Neural Network results without cutting based on hit time:
#
#
# Signal Efficiency: 94.45%
# Background Rejection: 71.27%
#
#
# Neural Network results using hit time with 30ps gaussian:
#
#
# Signal Efficiency: 99.61%
# Background Rejection: 91.45%
#
#
# Cut results by themselves for 30 ps Gaussian:
#
#
# Signal Efficiency: 94.19%
# Background Rejection: 96.05%

# %%
model.saveModel(model_number=2)#, overwrite=True)

# %%
model1=FilteringModel(tf_records_dir=Path('./filtering_records2000').resolve(), x_feature_description=['z_global', 'y_local','y_size', 'x_size'], loadModel=True, model_number=2)
model1.checkAccuracy()
# Out:
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# batches:  30
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# Compiling model with learning rate: 0.01
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step
# 100%|██████████| 7/7 [00:00<00:00, 19.50it/s]
# Overall Accuracy of Neural Network: 84.14%
# Fraction of Data that are Signal: 55.5%
#
# Neural Network results without cutting based on hit time:
#
#
# Signal Efficiency: 94.45%
# Background Rejection: 71.27%
#
#
# Neural Network results using hit time with 30ps gaussian:
#
#
# Signal Efficiency: 99.61%
# Background Rejection: 91.45%
#
#
# Cut results by themselves for 30 ps Gaussian:
#
#
# Signal Efficiency: 94.19%
# Background Rejection: 96.05%

# %%
model.plotROCcurve()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# 100%|██████████| 7/7 [00:00<00:00, 19.30it/s]
# Optimal threshold: 0.5404317378997803

# %%
model.checkAccuracy(threshold=.45)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step
# 100%|██████████| 7/7 [00:00<00:00, 19.50it/s]
# Overall Accuracy of Neural Network: 55.5%
# Fraction of Data that are Signal: 55.5%
#
# Neural Network results without cutting based on hit time:
#
#
# Signal Efficiency: 100.0%
# Background Rejection: 0.0%
#
#
# Neural Network results using hit time with 30ps gaussian:
#
#
# Signal Efficiency: 99.61%
# Background Rejection: 91.45%
#
#
# Cut results by themselves for 30 ps Gaussian:
#
#
# Signal Efficiency: 99.61%
# Background Rejection: 91.45%

# %%
model.saveModel(model_number=1)#,overwrite=True)

# %%
model.compareRejectedBIB(threshold=0.1)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step
# 100%|██████████| 45/45 [00:02<00:00, 20.31it/s]

# %%
x1=np.mean(model.rejected_by_nn['x_size'])
x2=np.mean(model.rejected_by_time['x_size'])
x3=np.mean(model.rejected_by_both['x_size'])
x4=np.mean(model.not_rejected['x_size'])
x5=np.mean(model.sigInfo['x_size'])
print(f'Mean x-size for BIB rejected by neural network: {x1}\nMean x-size for BIB rejected by hit time cut: {x2}\nMean x-size for BIB rejected by both: {x3}\nMean x-size for BIB that were not rejected by either: {x4}\nMean x-size for signal: {x5}')
# Out:
# Mean x-size for BIB rejected by neural network: 3.1163206100463867
# Mean x-size for BIB rejected by hit time cut: 2.5234274864196777
# Mean x-size for BIB rejected by both: 2.6297967433929443
# Mean x-size for BIB that were not rejected by either: 2.895397424697876
# Mean x-size for signal: 2.688544273376465

# %%
x1=np.mean(model.rejected_by_nn['y_size'])
x2=np.mean(model.rejected_by_time['y_size'])
x3=np.mean(model.rejected_by_both['y_size'])
x4=np.mean(model.not_rejected['y_size'])
x5=np.mean(model.sigInfo['y_size'])
print(f'Mean y-size for BIB rejected by neural network: {x1}\nMean y-size for BIB rejected by hit time cut: {x2}\nMean y-size for BIB rejected by both: {x3}\nMean y-size for BIB that were not rejected by either: {x4}\nMean y-size for signal: {x5}')
# Out:
# Mean y-size for BIB rejected by neural network: 3.003937005996704
# Mean y-size for BIB rejected by hit time cut: 2.4494075775146484
# Mean y-size for BIB rejected by both: 2.450772762298584
# Mean y-size for BIB that were not rejected by either: 1.8577406406402588
# Mean y-size for signal: 1.6993716955184937
